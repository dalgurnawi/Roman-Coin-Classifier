# %% [markdown]
# #### Importing Libraries

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import copy
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
import os
import timeit
import time
import glob
from natsort import natsorted
from tqdm import tqdm

# %%
# Defining paths
path ='data_files/data_del'
os.makedirs(path, exist_ok=True)

# %%
#Webpage of the coin site
url = "http://numismatics.org/ocre/results"

#To open a page, pass url to urlopen
page = urlopen(url)

#urlopen() returns an HTTPResponse object:
page

# %%
def extract_data(url,number):
    # Creating a dictionary of empty 
    data= {"record_id":[], "record_description":[], "Date": [], "Denomination": [], "Mint": [], "Obverse": [],
      "Reverse":[], "Reference":[], "Images":[]}
       
    #To open a page, pass url to urlopen
    page = urlopen(url)
    html_bytes = page.read()
    html = html_bytes.decode("utf-8")
    soup = BeautifulSoup(html, "html.parser")
    
    # All entries on a page are within the "col-md-12" class container. 
    # Asking BS4 to provide a list of all of these classes on a particular page 
    cont_list = soup.find_all("div", {"class": "col-md-12"})
        
    # Within each page are several other elements of interest, which will be retrieved using their specific elements
    for i in range(len(cont_list)):
        # Extract function removes the Tag or Navigable String from the parse three i.e. removes the specific element from the HTML document.
        # The extracted element i.e. record ID
        # Here we also make use of the re module, which is a built-in package from python.
        # It finds the href items from within a given text
        c = re.findall('href="(.+?)">',str(cont_list[i].extract()))
        data["record_id"].extend(c)

        # For the record description, we access the string content of a Tag object and then immediately removing it from the parse tree.      
        rec_des = cont_list[i].string.extract()        
        data["record_description"].append(rec_des)


    # Next step, we need to determine if the record has an image in the thumbnail.
    # If a thumbnail is present, then the record will have at least one image.    
    
    # Thumbnail images are denoted by the class "col-md-5 col-lg-4 pull-right"
    images = soup.find_all("div", {"class": "col-md-5 col-lg-4 pull-right"})


    for i in range(len(images)):
        # Extract the HTML content
        a_images = str(images[i].extract())
        
        if "thumbImage" in a_images:
            data["Images"].append("Yes")
        else:
            data["Images"].append("No")
        
    # Lastly, we will obtain the details for each record
    details = soup.find_all("dl", {"class": "dl-horizontal"})

    for i in range(len(details)):
        
        # Tags with DD have the details
        deets = re.findall('<dd>(.+?)</dd>', str(details[i].extract()))
        
        # Tags with DT have the Labels, which we will use to assign the details to the data.
        label = re.findall('<dt>(.+?)</dt>', str(details[i].extract()))
        
        for i in range(len(label)):
            data[label[i]].append(deets[i])
    

    
    df = pd.DataFrame(dict([(k,pd.Series(v)) for k,v in data.items()]))
    path ='data_files/data'
    df.to_csv(path + '/pages_'+str(number)+'.csv', encoding = 'utf-8')

# %%
basic = "http://numismatics.org/ocre/results?q=&start="
numbers = list(range(0,41720,20))

for i in tqdm (range(len(numbers))):
    url = basic + str(numbers[i])
    extract_data(url,numbers[i])
# Out:
# 100%|██████████| 2086/2086 [39:49<00:00,  1.15s/it]

# %%
# Merging together all the CSV files
# First, reading the path
file_path = "data_files/data"


#list all the files from the directory
file_list = os.listdir(file_path)
file_list_ordered = natsorted(file_list)

# %%
file_list_ordered
# Out:
# ['.DS_Store',
#  'pages_0.csv',
#  'pages_20.csv',
#  'pages_40.csv',
#  'pages_60.csv',
#  'pages_80.csv',
#  'pages_100.csv',
#  'pages_120.csv',
#  'pages_140.csv',
#  'pages_160.csv',
#  'pages_180.csv',
#  'pages_200.csv',
#  'pages_220.csv',
#  'pages_240.csv',
#  'pages_260.csv',
#  'pages_280.csv',
#  'pages_300.csv',
#  'pages_320.csv',
#  'pages_340.csv',
#  'pages_360.csv',
#  'pages_380.csv',
#  'pages_400.csv',
#  'pages_420.csv',
#  'pages_440.csv',
#  'pages_460.csv',
#  'pages_480.csv',
#  'pages_500.csv',
#  'pages_520.csv',
#  'pages_540.csv',
#  'pages_560.csv',
#  'pages_580.csv',
#  'pages_600.csv',
#  'pages_620.csv',
#  'pages_640.csv',
#  'pages_660.csv',
#  'pages_680.csv',
#  'pages_700.csv',
#  'pages_720.csv',
#  'pages_740.csv',
#  'pages_760.csv',
#  'pages_780.csv',
#  'pages_800.csv',
#  'pages_820.csv',
#  'pages_840.csv',
#  'pages_860.csv',
#  'pages_880.csv',
#  'pages_900.csv',
#  'pages_920.csv',
#  'pages_940.csv',
#  'pages_960.csv',
#  'pages_980.csv',
#  'pages_1000.csv',
#  'pages_1020.csv',
#  'pages_1040.csv',
#  'pages_1060.csv',
#  'pages_1080.csv',
#  'pages_1100.csv',
#  'pages_1120.csv',
#  'pages_1140.csv',
#  'pages_1160.csv',
#  'pages_1180.csv',
#  'pages_1200.csv',
#  'pages_1220.csv',
#  'pages_1240.csv',
#  'pages_1260.csv',
#  'pages_1280.csv',
#  'pages_1300.csv',
#  'pages_1320.csv',
#  'pages_1340.csv',
#  'pages_1360.csv',
#  'pages_1380.csv',
#  'pages_1400.csv',
#  'pages_1420.csv',
#  'pages_1440.csv',
#  'pages_1460.csv',
#  'pages_1480.csv',
#  'pages_1500.csv',
#  'pages_1520.csv',
#  'pages_1540.csv',
#  'pages_1560.csv',
#  'pages_1580.csv',
#  'pages_1600.csv',
#  'pages_1620.csv',
#  'pages_1640.csv',
#  'pages_1660.csv',
#  'pages_1680.csv',
#  'pages_1700.csv',
#  'pages_1720.csv',
#  'pages_1740.csv',
#  'pages_1760.csv',
#  'pages_1780.csv',
#  'pages_1800.csv',
#  'pages_1820.csv',
#  'pages_1840.csv',
#  'pages_1860.csv',
#  'pages_1880.csv',
#  'pages_1900.csv',
#  'pages_1920.csv',
#  'pages_1940.csv',
#  'pages_1960.csv',
#  'pages_1980.csv',
#  'pages_2000.csv',
#  'pages_2020.csv',
#  'pages_2040.csv',
#  'pages_2060.csv',
#  'pages_2080.csv',
#  'pages_2100.csv',
#  'pages_2120.csv',
#  'pages_2140.csv',
#  'pages_2160.csv',
#  'pages_2180.csv',
#  'pages_2200.csv',
#  'pages_2220.csv',
#  'pages_2240.csv',
#  'pages_2260.csv',
#  'pages_2280.csv',
#  'pages_2300.csv',
#  'pages_2320.csv',
#  'pages_2340.csv',
#  'pages_2360.csv',
#  'pages_2380.csv',
#  'pages_2400.csv',
#  'pages_2420.csv',
#  'pages_2440.csv',
#  'pages_2460.csv',
#  'pages_2480.csv',
#  'pages_2500.csv',
#  'pages_2520.csv',
#  'pages_2540.csv',
#  'pages_2560.csv',
#  'pages_2580.csv',
#  'pages_2600.csv',
#  'pages_2620.csv',
#  'pages_2640.csv',
#  'pages_2660.csv',
#  'pages_2680.csv',
#  'pages_2700.csv',
#  'pages_2720.csv',
#  'pages_2740.csv',
#  'pages_2760.csv',
#  'pages_2780.csv',
#  'pages_2800.csv',
#  'pages_2820.csv',
#  'pages_2840.csv',
#  'pages_2860.csv',
#  'pages_2880.csv',
#  'pages_2900.csv',
#  'pages_2920.csv',
#  'pages_2940.csv',
#  'pages_2960.csv',
#  'pages_2980.csv',
#  'pages_3000.csv',
#  'pages_3020.csv',
#  'pages_3040.csv',
#  'pages_3060.csv',
#  'pages_3080.csv',
#  'pages_3100.csv',
#  'pages_3120.csv',
#  'pages_3140.csv',
#  'pages_3160.csv',
#  'pages_3180.csv',
#  'pages_3200.csv',
#  'pages_3220.csv',
#  'pages_3240.csv',
#  'pages_3260.csv',
#  'pages_3280.csv',
#  'pages_3300.csv',
#  'pages_3320.csv',
#  'pages_3340.csv',
#  'pages_3360.csv',
#  'pages_3380.csv',
#  'pages_3400.csv',
#  'pages_3420.csv',
#  'pages_3440.csv',
#  'pages_3460.csv',
#  'pages_3480.csv',
#  'pages_3500.csv',
#  'pages_3520.csv',
#  'pages_3540.csv',
#  'pages_3560.csv',
#  'pages_3580.csv',
#  'pages_3600.csv',
#  'pages_3620.csv',
#  'pages_3640.csv',
#  'pages_3660.csv',
#  'pages_3680.csv',
#  'pages_3700.csv',
#  'pages_3720.csv',
#  'pages_3740.csv',
#  'pages_3760.csv',
#  'pages_3780.csv',
#  'pages_3800.csv',
#  'pages_3820.csv',
#  'pages_3840.csv',
#  'pages_3860.csv',
#  'pages_3880.csv',
#  'pages_3900.csv',
#  'pages_3920.csv',
#  'pages_3940.csv',
#  'pages_3960.csv',
#  'pages_3980.csv',
#  'pages_4000.csv',
#  'pages_4020.csv',
#  'pages_4040.csv',
#  'pages_4060.csv',
#  'pages_4080.csv',
#  'pages_4100.csv',
#  'pages_4120.csv',
#  'pages_4140.csv',
#  'pages_4160.csv',
#  'pages_4180.csv',
#  'pages_4200.csv',
#  'pages_4220.csv',
#  'pages_4240.csv',
#  'pages_4260.csv',
#  'pages_4280.csv',
#  'pages_4300.csv',
#  'pages_4320.csv',
#  'pages_4340.csv',
#  'pages_4360.csv',
#  'pages_4380.csv',
#  'pages_4400.csv',
#  'pages_4420.csv',
#  'pages_4440.csv',
#  'pages_4460.csv',
#  'pages_4480.csv',
#  'pages_4500.csv',
#  'pages_4520.csv',
#  'pages_4540.csv',
#  'pages_4560.csv',
#  'pages_4580.csv',
#  'pages_4600.csv',
#  'pages_4620.csv',
#  'pages_4640.csv',
#  'pages_4660.csv',
#  'pages_4680.csv',
#  'pages_4700.csv',
#  'pages_4720.csv',
#  'pages_4740.csv',
#  'pages_4760.csv',
#  'pages_4780.csv',
#  'pages_4800.csv',
#  'pages_4820.csv',
#  'pages_4840.csv',
#  'pages_4860.csv',
#  'pages_4880.csv',
#  'pages_4900.csv',
#  'pages_4920.csv',
#  'pages_4940.csv',
#  'pages_4960.csv',
#  'pages_4980.csv',
#  'pages_5000.csv',
#  'pages_5020.csv',
#  'pages_5040.csv',
#  'pages_5060.csv',
#  'pages_5080.csv',
#  'pages_5100.csv',
#  'pages_5120.csv',
#  'pages_5140.csv',
#  'pages_5160.csv',
#  'pages_5180.csv',
#  'pages_5200.csv',
#  'pages_5220.csv',
#  'pages_5240.csv',
#  'pages_5260.csv',
#  'pages_5280.csv',
#  'pages_5300.csv',
#  'pages_5320.csv',
#  'pages_5340.csv',
#  'pages_5360.csv',
#  'pages_5380.csv',
#  'pages_5400.csv',
#  'pages_5420.csv',
#  'pages_5440.csv',
#  'pages_5460.csv',
#  'pages_5480.csv',
#  'pages_5500.csv',
#  'pages_5520.csv',
#  'pages_5540.csv',
#  'pages_5560.csv',
#  'pages_5580.csv',
#  'pages_5600.csv',
#  'pages_5620.csv',
#  'pages_5640.csv',
#  'pages_5660.csv',
#  'pages_5680.csv',
#  'pages_5700.csv',
#  'pages_5720.csv',
#  'pages_5740.csv',
#  'pages_5760.csv',
#  'pages_5780.csv',
#  'pages_5800.csv',
#  'pages_5820.csv',
#  'pages_5840.csv',
#  'pages_5860.csv',
#  'pages_5880.csv',
#  'pages_5900.csv',
#  'pages_5920.csv',
#  'pages_5940.csv',
#  'pages_5960.csv',
#  'pages_5980.csv',
#  'pages_6000.csv',
#  'pages_6020.csv',
#  'pages_6040.csv',
#  'pages_6060.csv',
#  'pages_6080.csv',
#  'pages_6100.csv',
#  'pages_6120.csv',
#  'pages_6140.csv',
#  'pages_6160.csv',
#  'pages_6180.csv',
#  'pages_6200.csv',
#  'pages_6220.csv',
#  'pages_6240.csv',
#  'pages_6260.csv',
#  'pages_6280.csv',
#  'pages_6300.csv',
#  'pages_6320.csv',
#  'pages_6340.csv',
#  'pages_6360.csv',
#  'pages_6380.csv',
#  'pages_6400.csv',
#  'pages_6420.csv',
#  'pages_6440.csv',
#  'pages_6460.csv',
#  'pages_6480.csv',
#  'pages_6500.csv',
#  'pages_6520.csv',
#  'pages_6540.csv',
#  'pages_6560.csv',
#  'pages_6580.csv',
#  'pages_6600.csv',
#  'pages_6620.csv',
#  'pages_6640.csv',
#  'pages_6660.csv',
#  'pages_6680.csv',
#  'pages_6700.csv',
#  'pages_6720.csv',
#  'pages_6740.csv',
#  'pages_6760.csv',
#  'pages_6780.csv',
#  'pages_6800.csv',
#  'pages_6820.csv',
#  'pages_6840.csv',
#  'pages_6860.csv',
#  'pages_6880.csv',
#  'pages_6900.csv',
#  'pages_6920.csv',
#  'pages_6940.csv',
#  'pages_6960.csv',
#  'pages_6980.csv',
#  'pages_7000.csv',
#  'pages_7020.csv',
#  'pages_7040.csv',
#  'pages_7060.csv',
#  'pages_7080.csv',
#  'pages_7100.csv',
#  'pages_7120.csv',
#  'pages_7140.csv',
#  'pages_7160.csv',
#  'pages_7180.csv',
#  'pages_7200.csv',
#  'pages_7220.csv',
#  'pages_7240.csv',
#  'pages_7260.csv',
#  'pages_7280.csv',
#  'pages_7300.csv',
#  'pages_7320.csv',
#  'pages_7340.csv',
#  'pages_7360.csv',
#  'pages_7380.csv',
#  'pages_7400.csv',
#  'pages_7420.csv',
#  'pages_7440.csv',
#  'pages_7460.csv',
#  'pages_7480.csv',
#  'pages_7500.csv',
#  'pages_7520.csv',
#  'pages_7540.csv',
#  'pages_7560.csv',
#  'pages_7580.csv',
#  'pages_7600.csv',
#  'pages_7620.csv',
#  'pages_7640.csv',
#  'pages_7660.csv',
#  'pages_7680.csv',
#  'pages_7700.csv',
#  'pages_7720.csv',
#  'pages_7740.csv',
#  'pages_7760.csv',
#  'pages_7780.csv',
#  'pages_7800.csv',
#  'pages_7820.csv',
#  'pages_7840.csv',
#  'pages_7860.csv',
#  'pages_7880.csv',
#  'pages_7900.csv',
#  'pages_7920.csv',
#  'pages_7940.csv',
#  'pages_7960.csv',
#  'pages_7980.csv',
#  'pages_8000.csv',
#  'pages_8020.csv',
#  'pages_8040.csv',
#  'pages_8060.csv',
#  'pages_8080.csv',
#  'pages_8100.csv',
#  'pages_8120.csv',
#  'pages_8140.csv',
#  'pages_8160.csv',
#  'pages_8180.csv',
#  'pages_8200.csv',
#  'pages_8220.csv',
#  'pages_8240.csv',
#  'pages_8260.csv',
#  'pages_8280.csv',
#  'pages_8300.csv',
#  'pages_8320.csv',
#  'pages_8340.csv',
#  'pages_8360.csv',
#  'pages_8380.csv',
#  'pages_8400.csv',
#  'pages_8420.csv',
#  'pages_8440.csv',
#  'pages_8460.csv',
#  'pages_8480.csv',
#  'pages_8500.csv',
#  'pages_8520.csv',
#  'pages_8540.csv',
#  'pages_8560.csv',
#  'pages_8580.csv',
#  'pages_8600.csv',
#  'pages_8620.csv',
#  'pages_8640.csv',
#  'pages_8660.csv',
#  'pages_8680.csv',
#  'pages_8700.csv',
#  'pages_8720.csv',
#  'pages_8740.csv',
#  'pages_8760.csv',
#  'pages_8780.csv',
#  'pages_8800.csv',
#  'pages_8820.csv',
#  'pages_8840.csv',
#  'pages_8860.csv',
#  'pages_8880.csv',
#  'pages_8900.csv',
#  'pages_8920.csv',
#  'pages_8940.csv',
#  'pages_8960.csv',
#  'pages_8980.csv',
#  'pages_9000.csv',
#  'pages_9020.csv',
#  'pages_9040.csv',
#  'pages_9060.csv',
#  'pages_9080.csv',
#  'pages_9100.csv',
#  'pages_9120.csv',
#  'pages_9140.csv',
#  'pages_9160.csv',
#  'pages_9180.csv',
#  'pages_9200.csv',
#  'pages_9220.csv',
#  'pages_9240.csv',
#  'pages_9260.csv',
#  'pages_9280.csv',
#  'pages_9300.csv',
#  'pages_9320.csv',
#  'pages_9340.csv',
#  'pages_9360.csv',
#  'pages_9380.csv',
#  'pages_9400.csv',
#  'pages_9420.csv',
#  'pages_9440.csv',
#  'pages_9460.csv',
#  'pages_9480.csv',
#  'pages_9500.csv',
#  'pages_9520.csv',
#  'pages_9540.csv',
#  'pages_9560.csv',
#  'pages_9580.csv',
#  'pages_9600.csv',
#  'pages_9620.csv',
#  'pages_9640.csv',
#  'pages_9660.csv',
#  'pages_9680.csv',
#  'pages_9700.csv',
#  'pages_9720.csv',
#  'pages_9740.csv',
#  'pages_9760.csv',
#  'pages_9780.csv',
#  'pages_9800.csv',
#  'pages_9820.csv',
#  'pages_9840.csv',
#  'pages_9860.csv',
#  'pages_9880.csv',
#  'pages_9900.csv',
#  'pages_9920.csv',
#  'pages_9940.csv',
#  'pages_9960.csv',
#  'pages_9980.csv',
#  'pages_10000.csv',
#  'pages_10020.csv',
#  'pages_10040.csv',
#  'pages_10060.csv',
#  'pages_10080.csv',
#  'pages_10100.csv',
#  'pages_10120.csv',
#  'pages_10140.csv',
#  'pages_10160.csv',
#  'pages_10180.csv',
#  'pages_10200.csv',
#  'pages_10220.csv',
#  'pages_10240.csv',
#  'pages_10260.csv',
#  'pages_10280.csv',
#  'pages_10300.csv',
#  'pages_10320.csv',
#  'pages_10340.csv',
#  'pages_10360.csv',
#  'pages_10380.csv',
#  'pages_10400.csv',
#  'pages_10420.csv',
#  'pages_10440.csv',
#  'pages_10460.csv',
#  'pages_10480.csv',
#  'pages_10500.csv',
#  'pages_10520.csv',
#  'pages_10540.csv',
#  'pages_10560.csv',
#  'pages_10580.csv',
#  'pages_10600.csv',
#  'pages_10620.csv',
#  'pages_10640.csv',
#  'pages_10660.csv',
#  'pages_10680.csv',
#  'pages_10700.csv',
#  'pages_10720.csv',
#  'pages_10740.csv',
#  'pages_10760.csv',
#  'pages_10780.csv',
#  'pages_10800.csv',
#  'pages_10820.csv',
#  'pages_10840.csv',
#  'pages_10860.csv',
#  'pages_10880.csv',
#  'pages_10900.csv',
#  'pages_10920.csv',
#  'pages_10940.csv',
#  'pages_10960.csv',
#  'pages_10980.csv',
#  'pages_11000.csv',
#  'pages_11020.csv',
#  'pages_11040.csv',
#  'pages_11060.csv',
#  'pages_11080.csv',
#  'pages_11100.csv',
#  'pages_11120.csv',
#  'pages_11140.csv',
#  'pages_11160.csv',
#  'pages_11180.csv',
#  'pages_11200.csv',
#  'pages_11220.csv',
#  'pages_11240.csv',
#  'pages_11260.csv',
#  'pages_11280.csv',
#  'pages_11300.csv',
#  'pages_11320.csv',
#  'pages_11340.csv',
#  'pages_11360.csv',
#  'pages_11380.csv',
#  'pages_11400.csv',
#  'pages_11420.csv',
#  'pages_11440.csv',
#  'pages_11460.csv',
#  'pages_11480.csv',
#  'pages_11500.csv',
#  'pages_11520.csv',
#  'pages_11540.csv',
#  'pages_11560.csv',
#  'pages_11580.csv',
#  'pages_11600.csv',
#  'pages_11620.csv',
#  'pages_11640.csv',
#  'pages_11660.csv',
#  'pages_11680.csv',
#  'pages_11700.csv',
#  'pages_11720.csv',
#  'pages_11740.csv',
#  'pages_11760.csv',
#  'pages_11780.csv',
#  'pages_11800.csv',
#  'pages_11820.csv',
#  'pages_11840.csv',
#  'pages_11860.csv',
#  'pages_11880.csv',
#  'pages_11900.csv',
#  'pages_11920.csv',
#  'pages_11940.csv',
#  'pages_11960.csv',
#  'pages_11980.csv',
#  'pages_12000.csv',
#  'pages_12020.csv',
#  'pages_12040.csv',
#  'pages_12060.csv',
#  'pages_12080.csv',
#  'pages_12100.csv',
#  'pages_12120.csv',
#  'pages_12140.csv',
#  'pages_12160.csv',
#  'pages_12180.csv',
#  'pages_12200.csv',
#  'pages_12220.csv',
#  'pages_12240.csv',
#  'pages_12260.csv',
#  'pages_12280.csv',
#  'pages_12300.csv',
#  'pages_12320.csv',
#  'pages_12340.csv',
#  'pages_12360.csv',
#  'pages_12380.csv',
#  'pages_12400.csv',
#  'pages_12420.csv',
#  'pages_12440.csv',
#  'pages_12460.csv',
#  'pages_12480.csv',
#  'pages_12500.csv',
#  'pages_12520.csv',
#  'pages_12540.csv',
#  'pages_12560.csv',
#  'pages_12580.csv',
#  'pages_12600.csv',
#  'pages_12620.csv',
#  'pages_12640.csv',
#  'pages_12660.csv',
#  'pages_12680.csv',
#  'pages_12700.csv',
#  'pages_12720.csv',
#  'pages_12740.csv',
#  'pages_12760.csv',
#  'pages_12780.csv',
#  'pages_12800.csv',
#  'pages_12820.csv',
#  'pages_12840.csv',
#  'pages_12860.csv',
#  'pages_12880.csv',
#  'pages_12900.csv',
#  'pages_12920.csv',
#  'pages_12940.csv',
#  'pages_12960.csv',
#  'pages_12980.csv',
#  'pages_13000.csv',
#  'pages_13020.csv',
#  'pages_13040.csv',
#  'pages_13060.csv',
#  'pages_13080.csv',
#  'pages_13100.csv',
#  'pages_13120.csv',
#  'pages_13140.csv',
#  'pages_13160.csv',
#  'pages_13180.csv',
#  'pages_13200.csv',
#  'pages_13220.csv',
#  'pages_13240.csv',
#  'pages_13260.csv',
#  'pages_13280.csv',
#  'pages_13300.csv',
#  'pages_13320.csv',
#  'pages_13340.csv',
#  'pages_13360.csv',
#  'pages_13380.csv',
#  'pages_13400.csv',
#  'pages_13420.csv',
#  'pages_13440.csv',
#  'pages_13460.csv',
#  'pages_13480.csv',
#  'pages_13500.csv',
#  'pages_13520.csv',
#  'pages_13540.csv',
#  'pages_13560.csv',
#  'pages_13580.csv',
#  'pages_13600.csv',
#  'pages_13620.csv',
#  'pages_13640.csv',
#  'pages_13660.csv',
#  'pages_13680.csv',
#  'pages_13700.csv',
#  'pages_13720.csv',
#  'pages_13740.csv',
#  'pages_13760.csv',
#  'pages_13780.csv',
#  'pages_13800.csv',
#  'pages_13820.csv',
#  'pages_13840.csv',
#  'pages_13860.csv',
#  'pages_13880.csv',
#  'pages_13900.csv',
#  'pages_13920.csv',
#  'pages_13940.csv',
#  'pages_13960.csv',
#  'pages_13980.csv',
#  'pages_14000.csv',
#  'pages_14020.csv',
#  'pages_14040.csv',
#  'pages_14060.csv',
#  'pages_14080.csv',
#  'pages_14100.csv',
#  'pages_14120.csv',
#  'pages_14140.csv',
#  'pages_14160.csv',
#  'pages_14180.csv',
#  'pages_14200.csv',
#  'pages_14220.csv',
#  'pages_14240.csv',
#  'pages_14260.csv',
#  'pages_14280.csv',
#  'pages_14300.csv',
#  'pages_14320.csv',
#  'pages_14340.csv',
#  'pages_14360.csv',
#  'pages_14380.csv',
#  'pages_14400.csv',
#  'pages_14420.csv',
#  'pages_14440.csv',
#  'pages_14460.csv',
#  'pages_14480.csv',
#  'pages_14500.csv',
#  'pages_14520.csv',
#  'pages_14540.csv',
#  'pages_14560.csv',
#  'pages_14580.csv',
#  'pages_14600.csv',
#  'pages_14620.csv',
#  'pages_14640.csv',
#  'pages_14660.csv',
#  'pages_14680.csv',
#  'pages_14700.csv',
#  'pages_14720.csv',
#  'pages_14740.csv',
#  'pages_14760.csv',
#  'pages_14780.csv',
#  'pages_14800.csv',
#  'pages_14820.csv',
#  'pages_14840.csv',
#  'pages_14860.csv',
#  'pages_14880.csv',
#  'pages_14900.csv',
#  'pages_14920.csv',
#  'pages_14940.csv',
#  'pages_14960.csv',
#  'pages_14980.csv',
#  'pages_15000.csv',
#  'pages_15020.csv',
#  'pages_15040.csv',
#  'pages_15060.csv',
#  'pages_15080.csv',
#  'pages_15100.csv',
#  'pages_15120.csv',
#  'pages_15140.csv',
#  'pages_15160.csv',
#  'pages_15180.csv',
#  'pages_15200.csv',
#  'pages_15220.csv',
#  'pages_15240.csv',
#  'pages_15260.csv',
#  'pages_15280.csv',
#  'pages_15300.csv',
#  'pages_15320.csv',
#  'pages_15340.csv',
#  'pages_15360.csv',
#  'pages_15380.csv',
#  'pages_15400.csv',
#  'pages_15420.csv',
#  'pages_15440.csv',
#  'pages_15460.csv',
#  'pages_15480.csv',
#  'pages_15500.csv',
#  'pages_15520.csv',
#  'pages_15540.csv',
#  'pages_15560.csv',
#  'pages_15580.csv',
#  'pages_15600.csv',
#  'pages_15620.csv',
#  'pages_15640.csv',
#  'pages_15660.csv',
#  'pages_15680.csv',
#  'pages_15700.csv',
#  'pages_15720.csv',
#  'pages_15740.csv',
#  'pages_15760.csv',
#  'pages_15780.csv',
#  'pages_15800.csv',
#  'pages_15820.csv',
#  'pages_15840.csv',
#  'pages_15860.csv',
#  'pages_15880.csv',
#  'pages_15900.csv',
#  'pages_15920.csv',
#  'pages_15940.csv',
#  'pages_15960.csv',
#  'pages_15980.csv',
#  'pages_16000.csv',
#  'pages_16020.csv',
#  'pages_16040.csv',
#  'pages_16060.csv',
#  'pages_16080.csv',
#  'pages_16100.csv',
#  'pages_16120.csv',
#  'pages_16140.csv',
#  'pages_16160.csv',
#  'pages_16180.csv',
#  'pages_16200.csv',
#  'pages_16220.csv',
#  'pages_16240.csv',
#  'pages_16260.csv',
#  'pages_16280.csv',
#  'pages_16300.csv',
#  'pages_16320.csv',
#  'pages_16340.csv',
#  'pages_16360.csv',
#  'pages_16380.csv',
#  'pages_16400.csv',
#  'pages_16420.csv',
#  'pages_16440.csv',
#  'pages_16460.csv',
#  'pages_16480.csv',
#  'pages_16500.csv',
#  'pages_16520.csv',
#  'pages_16540.csv',
#  'pages_16560.csv',
#  'pages_16580.csv',
#  'pages_16600.csv',
#  'pages_16620.csv',
#  'pages_16640.csv',
#  'pages_16660.csv',
#  'pages_16680.csv',
#  'pages_16700.csv',
#  'pages_16720.csv',
#  'pages_16740.csv',
#  'pages_16760.csv',
#  'pages_16780.csv',
#  'pages_16800.csv',
#  'pages_16820.csv',
#  'pages_16840.csv',
#  'pages_16860.csv',
#  'pages_16880.csv',
#  'pages_16900.csv',
#  'pages_16920.csv',
#  'pages_16940.csv',
#  'pages_16960.csv',
#  'pages_16980.csv',
#  'pages_17000.csv',
#  'pages_17020.csv',
#  'pages_17040.csv',
#  'pages_17060.csv',
#  'pages_17080.csv',
#  'pages_17100.csv',
#  'pages_17120.csv',
#  'pages_17140.csv',
#  'pages_17160.csv',
#  'pages_17180.csv',
#  'pages_17200.csv',
#  'pages_17220.csv',
#  'pages_17240.csv',
#  'pages_17260.csv',
#  'pages_17280.csv',
#  'pages_17300.csv',
#  'pages_17320.csv',
#  'pages_17340.csv',
#  'pages_17360.csv',
#  'pages_17380.csv',
#  'pages_17400.csv',
#  'pages_17420.csv',
#  'pages_17440.csv',
#  'pages_17460.csv',
#  'pages_17480.csv',
#  'pages_17500.csv',
#  'pages_17520.csv',
#  'pages_17540.csv',
#  'pages_17560.csv',
#  'pages_17580.csv',
#  'pages_17600.csv',
#  'pages_17620.csv',
#  'pages_17640.csv',
#  'pages_17660.csv',
#  'pages_17680.csv',
#  'pages_17700.csv',
#  'pages_17720.csv',
#  'pages_17740.csv',
#  'pages_17760.csv',
#  'pages_17780.csv',
#  'pages_17800.csv',
#  'pages_17820.csv',
#  'pages_17840.csv',
#  'pages_17860.csv',
#  'pages_17880.csv',
#  'pages_17900.csv',
#  'pages_17920.csv',
#  'pages_17940.csv',
#  'pages_17960.csv',
#  'pages_17980.csv',
#  'pages_18000.csv',
#  'pages_18020.csv',
#  'pages_18040.csv',
#  'pages_18060.csv',
#  'pages_18080.csv',
#  'pages_18100.csv',
#  'pages_18120.csv',
#  'pages_18140.csv',
#  'pages_18160.csv',
#  'pages_18180.csv',
#  'pages_18200.csv',
#  'pages_18220.csv',
#  'pages_18240.csv',
#  'pages_18260.csv',
#  'pages_18280.csv',
#  'pages_18300.csv',
#  'pages_18320.csv',
#  'pages_18340.csv',
#  'pages_18360.csv',
#  'pages_18380.csv',
#  'pages_18400.csv',
#  'pages_18420.csv',
#  'pages_18440.csv',
#  'pages_18460.csv',
#  'pages_18480.csv',
#  'pages_18500.csv',
#  'pages_18520.csv',
#  'pages_18540.csv',
#  'pages_18560.csv',
#  'pages_18580.csv',
#  'pages_18600.csv',
#  'pages_18620.csv',
#  'pages_18640.csv',
#  'pages_18660.csv',
#  'pages_18680.csv',
#  'pages_18700.csv',
#  'pages_18720.csv',
#  'pages_18740.csv',
#  'pages_18760.csv',
#  'pages_18780.csv',
#  'pages_18800.csv',
#  'pages_18820.csv',
#  'pages_18840.csv',
#  'pages_18860.csv',
#  'pages_18880.csv',
#  'pages_18900.csv',
#  'pages_18920.csv',
#  'pages_18940.csv',
#  'pages_18960.csv',
#  'pages_18980.csv',
#  'pages_19000.csv',
#  'pages_19020.csv',
#  'pages_19040.csv',
#  'pages_19060.csv',
#  'pages_19080.csv',
#  'pages_19100.csv',
#  'pages_19120.csv',
#  'pages_19140.csv',
#  'pages_19160.csv',
#  'pages_19180.csv',
#  'pages_19200.csv',
#  'pages_19220.csv',
#  'pages_19240.csv',
#  'pages_19260.csv',
#  'pages_19280.csv',
#  'pages_19300.csv',
#  'pages_19320.csv',
#  'pages_19340.csv',
#  'pages_19360.csv',
#  'pages_19380.csv',
#  'pages_19400.csv',
#  'pages_19420.csv',
#  'pages_19440.csv',
#  'pages_19460.csv',
#  'pages_19480.csv',
#  'pages_19500.csv',
#  'pages_19520.csv',
#  'pages_19540.csv',
#  'pages_19560.csv',
#  'pages_19580.csv',
#  'pages_19600.csv',
#  'pages_19620.csv',
#  'pages_19640.csv',
#  'pages_19660.csv',
#  'pages_19680.csv',
#  'pages_19700.csv',
#  'pages_19720.csv',
#  'pages_19740.csv',
#  'pages_19760.csv',
#  'pages_19780.csv',
#  'pages_19800.csv',
#  'pages_19820.csv',
#  'pages_19840.csv',
#  'pages_19860.csv',
#  'pages_19880.csv',
#  'pages_19900.csv',
#  'pages_19920.csv',
#  'pages_19940.csv',
#  'pages_19960.csv',
#  ...]

# %%
# Taking a look at the individual file created
df_temp = pd.read_csv('data_files/data/pages_0.csv')
df_temp.head()
# Out:
#    Unnamed: 0           record_id                  record_description  \
# 0           0  id/ric.1(2).aug.1A  RIC I (second edition) Augustus 1A
# 1           1  id/ric.1(2).aug.1B  RIC I (second edition) Augustus 1B
# 2           2  id/ric.1(2).aug.2A  RIC I (second edition) Augustus 2A
# 3           3  id/ric.1(2).aug.2B  RIC I (second edition) Augustus 2B
# 4           4   id/ric.1(2).aug.3   RIC I (second edition) Augustus 3
#
#               Date Denomination     Mint  \
# 0  25 BCE - 23 BCE    Quinarius  Emerita
# 1  25 BCE - 23 BCE    Quinarius  Emerita
# 2  25 BCE - 23 BCE     Denarius  Emerita
# 3  25 BCE - 23 BCE     Denarius  Emerita
# 4  25 BCE - 23 BCE     Denarius  Emerita
#
#                                              Obverse  \
# 0               AVGVST: Head of Augustus, bare, left
# 1               AVGVST: Head of Augustus, bare, left
# 2   IMP CAESAR AVGVST: Head of Augustus, bare, right
# 3    IMP CAESAR AVGVST: Head of Augustus, bare, left
# 4  IMP CAESAR AVGVSTVS: Head of Augustus, bare, r...
#
#                                              Reverse  Reference Images
# 0  P CARISI LEG: Victory standing right, placing ...        NaN    Yes
# 1  P CARISI LEG: Victory standing right, placing ...        NaN    Yes
# 2  P CARISIVS LEG PRO PR: Round shield, spear-hea...        NaN    Yes
# 3  P CARISIVS LEG PRO PR: Round shield, spear-hea...        NaN    Yes
# 4  P CARISIVS LEG PRO PR: Round shield, spear-hea...        NaN    Yes

# %%
# Concatenating the files together to a single file

#Concatenating the files
df_concat = pd.DataFrame()
#append all files together
for file in tqdm(range(0,41700,20)):

            #Reading CSV from filepath
            df_temp = pd.read_csv(file_path+"/pages_"+str(file)+".csv")

            # Replace empty values with NaNs
            df_temp['Date'].replace('',np.nan, inplace=True)
            df_temp['Images'].replace('',np.nan,inplace=True)
            
            #Dropping rows that do no have images or dates
            #df_temp.dropna(subset=['Date','Images'], inplace=True)
            
            #Filtering rows where record has an image
            #df_temp = df_temp[df_temp['Images'].str.contains("Yes")]
            
            #Concatenating files
            df_concat = pd.concat([df_concat, df_temp], ignore_index=True)

df_concat.head()
# Out:
# 100%|██████████| 2085/2085 [00:07<00:00, 272.79it/s]
#    Unnamed: 0           record_id                  record_description  \
# 0           0  id/ric.1(2).aug.1A  RIC I (second edition) Augustus 1A
# 1           1  id/ric.1(2).aug.1B  RIC I (second edition) Augustus 1B
# 2           2  id/ric.1(2).aug.2A  RIC I (second edition) Augustus 2A
# 3           3  id/ric.1(2).aug.2B  RIC I (second edition) Augustus 2B
# 4           4   id/ric.1(2).aug.3   RIC I (second edition) Augustus 3
#
#               Date Denomination     Mint  \
# 0  25 BCE - 23 BCE    Quinarius  Emerita
# 1  25 BCE - 23 BCE    Quinarius  Emerita
# 2  25 BCE - 23 BCE     Denarius  Emerita
# 3  25 BCE - 23 BCE     Denarius  Emerita
# 4  25 BCE - 23 BCE     Denarius  Emerita
#
#                                              Obverse  \
# 0               AVGVST: Head of Augustus, bare, left
# 1               AVGVST: Head of Augustus, bare, left
# 2   IMP CAESAR AVGVST: Head of Augustus, bare, right
# 3    IMP CAESAR AVGVST: Head of Augustus, bare, left
# 4  IMP CAESAR AVGVSTVS: Head of Augustus, bare, r...
#
#                                              Reverse  Reference Images
# 0  P CARISI LEG: Victory standing right, placing ...        NaN    Yes
# 1  P CARISI LEG: Victory standing right, placing ...        NaN    Yes
# 2  P CARISIVS LEG PRO PR: Round shield, spear-hea...        NaN    Yes
# 3  P CARISIVS LEG PRO PR: Round shield, spear-hea...        NaN    Yes
# 4  P CARISIVS LEG PRO PR: Round shield, spear-hea...        NaN    Yes

# %%
# Save file
df_concat.to_csv('data_files/data_concat/concatenated_data.csv', sep=';', index=False)

# %%
# Import concatenated file
df = pd.read_csv('data_files/data_concat/concatenated_data.csv', sep=';')
df['record_id'] = df['record_id'].str.replace('id/','')
df = df.drop(df.columns[0], axis=1)
df.head()
# Out:
#          record_id                  record_description             Date  \
# 0  ric.1(2).aug.1A  RIC I (second edition) Augustus 1A  25 BCE - 23 BCE
# 1  ric.1(2).aug.1B  RIC I (second edition) Augustus 1B  25 BCE - 23 BCE
# 2  ric.1(2).aug.2A  RIC I (second edition) Augustus 2A  25 BCE - 23 BCE
# 3  ric.1(2).aug.2B  RIC I (second edition) Augustus 2B  25 BCE - 23 BCE
# 4   ric.1(2).aug.3   RIC I (second edition) Augustus 3  25 BCE - 23 BCE
#
#   Denomination     Mint                                            Obverse  \
# 0    Quinarius  Emerita               AVGVST: Head of Augustus, bare, left
# 1    Quinarius  Emerita               AVGVST: Head of Augustus, bare, left
# 2     Denarius  Emerita   IMP CAESAR AVGVST: Head of Augustus, bare, right
# 3     Denarius  Emerita    IMP CAESAR AVGVST: Head of Augustus, bare, left
# 4     Denarius  Emerita  IMP CAESAR AVGVSTVS: Head of Augustus, bare, r...
#
#                                              Reverse  Reference Images
# 0  P CARISI LEG: Victory standing right, placing ...        NaN    Yes
# 1  P CARISI LEG: Victory standing right, placing ...        NaN    Yes
# 2  P CARISIVS LEG PRO PR: Round shield, spear-hea...        NaN    Yes
# 3  P CARISIVS LEG PRO PR: Round shield, spear-hea...        NaN    Yes
# 4  P CARISIVS LEG PRO PR: Round shield, spear-hea...        NaN    Yes

# %%
#The way the link is structured is as follows:
# The main part of the hyperlink is https://numismatics.org/ocre/id/
# Followed by the record ID in the DataFrame record_ id ric.1(2).aug.1A
# Once there, it provides an option to download the CSV File with links to the images

url2 = "https://numismatics.org/ocre/id/ric.1(2).aug.1A"
page = urlopen(url2)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
# The "Download CSV" Link is in the "col-md-12" a container 
step_1 = soup.find_all("div", {"class": "col-md-12"})

# It is always the third (zero indexed) "col-md-12" container
link = step_1[2].find('h3').find('a')

# Select the href attribute of the 'a' tag
href = link['href']

print(href)
# Out:
# http://nomisma.org/query?query=PREFIX%20rdf%3A%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.w3.org%2F1999%2F02%2F22-rdf-syntax-ns%23%3E%0APREFIX%20crm%3A%09%3Chttp%3A%2F%2Fwww.cidoc-crm.org%2Fcidoc-crm%2F%3E%0APREFIX%20dcterms%3A%20%20%3Chttp%3A%2F%2Fpurl.org%2Fdc%2Fterms%2F%3E%0APREFIX%20nm%3A%20%20%20%20%20%20%20%3Chttp%3A%2F%2Fnomisma.org%2Fid%2F%3E%0APREFIX%20nmo%3A%09%3Chttp%3A%2F%2Fnomisma.org%2Fontology%23%3E%0APREFIX%20skos%3A%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0APREFIX%20foaf%3A%09%3Chttp%3A%2F%2Fxmlns.com%2Ffoaf%2F0.1%2F%3E%0APREFIX%20rdfs%3A%09%3Chttp%3A%2F%2Fwww.w3.org%2F2000%2F01%2Frdf-schema%23%3E%0APREFIX%20void%3A%09%3Chttp%3A%2F%2Frdfs.org%2Fns%2Fvoid%23%3E%0APREFIX%20geo%3A%09%3Chttp%3A%2F%2Fwww.w3.org%2F2003%2F01%2Fgeo%2Fwgs84_pos%23%3E%0APREFIX%20edm%3A%20%3Chttp%3A%2F%2Fwww.europeana.eu%2Fschemas%2Fedm%2F%3E%0A%0ASELECT%20DISTINCT%20%3Fobject%20%3Ftitle%20%28group_concat%28%3Fidentifier%3B%20separator%3D%22%7C%7C%22%29%20as%20%3Fidentifiers%29%20%3FfindUri%20%3Ffindspot%20%3Fhoard%20%3Fcollection%20%3Fpublisher%20%3Fdataset%20%3FdatasetTitle%20%3Fweight%20%3Faxis%20%3Fdiameter%20%3FobvThumb%20%3FrevThumb%20%3FobvRef%20%3FrevRef%20%3FcomThumb%20%3FcomRef%20%3FobvManifest%20%3FrevManifest%20%3FcomManifest%20%3Fmodel%20WHERE%20%7B%0A%7B%20%3Fobject%20a%20nmo%3ANumismaticObject%20%3B%0A%20nmo%3AhasTypeSeriesItem%20%3Chttp%3A%2F%2Fnumismatics.org%2Focre%2Fid%2Fric.1%282%29.aug.1A%3E%7D%0AUNION%20%7B%20%3Chttp%3A%2F%2Fnumismatics.org%2Focre%2Fid%2Fric.1%282%29.aug.1A%3E%20skos%3AexactMatch%20%3Fmatch%20.%0A%3Fobject%20nmo%3AhasTypeSeriesItem%20%3Fmatch%20%3B%0A%20%20a%20nmo%3ANumismaticObject%20%7D%0AUNION%20%7B%20%3Fbroader%20skos%3Abroader%2B%20%3Chttp%3A%2F%2Fnumismatics.org%2Focre%2Fid%2Fric.1%282%29.aug.1A%3E%20.%0A%3Fobject%20nmo%3AhasTypeSeriesItem%20%3Fbroader%20%3B%0A%20%20a%20nmo%3ANumismaticObject%20%7D%0AUNION%20%7B%20%3Fbroader%20skos%3Abroader%2B%20%3Chttp%3A%2F%2Fnumismatics.org%2Focre%2Fid%2Fric.1%282%29.aug.1A%3E%20.%0A%3Fbroader%20skos%3AexactMatch%20%3Fmatch%20.%0A%3Fobject%20nmo%3AhasTypeSeriesItem%20%3Fmatch%20%3B%0A%20%20a%20nmo%3ANumismaticObject%20%7D%0A%3Fobject%20dcterms%3Atitle%20%3Ftitle%20.%0AOPTIONAL%20%7B%20%3Fobject%20dcterms%3Aidentifier%20%3Fidentifier%7D%0AOPTIONAL%20%7B%20%3Fobject%20nmo%3AhasCollection%20%3FcolUri%20.%0A%3FcolUri%20skos%3AprefLabel%20%3Fcollection%20FILTER%28langMatches%28lang%28%3Fcollection%29%2C%20%22EN%22%29%29%7D%0A%3Fobject%20void%3AinDataset%20%3Fdataset%20.%0A%3Fdataset%20dcterms%3Apublisher%20%3Fpublisher%20FILTER%20%28lang%28%3Fpublisher%29%20%3D%20%22%22%20%7C%7C%20langMatches%28lang%28%3Fpublisher%29%2C%20%22en%22%29%29%20.%0A%3Fdataset%20dcterms%3Atitle%20%3FdatasetTitle%20FILTER%20%28lang%28%3FdatasetTitle%29%20%3D%20%22%22%20%7C%7C%20langMatches%28lang%28%3FdatasetTitle%29%2C%20%22en%22%29%29%20.%0AOPTIONAL%7B%20%3Fobject%20nmo%3AhasFindspot%2Fcrm%3AP7_took_place_at%2Fcrm%3AP89_falls_within%20%3FfindUri%20.%0A%20%20%3FfindUri%20a%20crm%3AE53_Place%20%3B%0A%20%20rdfs%3Alabel%20%3Ffindspot%20%7D%0AOPTIONAL%20%7B%3Fobject%20dcterms%3AisPartOf%20%3Fhoard%20.%0A%20%3Fhoard%20a%20nmo%3AHoard%20%3B%0A%20%09skos%3AprefLabel%20%3Ffindspot%20FILTER%28langMatches%28lang%28%3Ffindspot%29%2C%20%22EN%22%29%29%20%7D%0AOPTIONAL%20%7B%20%3Fobject%20nmo%3AhasWeight%20%3Fweight%20%7D%0AOPTIONAL%20%7B%20%3Fobject%20nmo%3AhasAxis%20%3Faxis%20%7D%0AOPTIONAL%20%7B%20%3Fobject%20nmo%3AhasDiameter%20%3Fdiameter%20%7D%0AOPTIONAL%20%7B%20%3Fobject%20foaf%3Athumbnail%20%3FcomThumb%20%7D%0AOPTIONAL%20%7B%20%3Fobject%20foaf%3Adepiction%20%3FcomRef%20%0A%09OPTIONAL%20%7B%20%3FcomRef%20dcterms%3AisReferencedBy%20%3FcomManifest%20%7D%7D%0AOPTIONAL%20%7B%20%3Fobject%20nmo%3AhasObverse%2Ffoaf%3Athumbnail%20%3FobvThumb%20%7D%0AOPTIONAL%20%7B%20%3Fobject%20nmo%3AhasObverse%20%3Fobverse%20.%0A%3Fobverse%20foaf%3Adepiction%20%3FobvRef%0A%09OPTIONAL%20%7B%20%3FobvRef%20dcterms%3AisReferencedBy%20%3FobvManifest%20%7D%7D%0AOPTIONAL%20%7B%20%3Fobject%20n ...

# %%
def extract_csv(dataframe,start):
    path2 = "data_files/data_csv_content"
    checkpoint = 0

    for id in tqdm (range(start, len(dataframe["record_id"]))):

        checkpoint =+ 1

        #The record ID is always in the format id/record_id. As a result, we will split the query and take the second element.
        rec_id = str(dataframe["record_id"].iloc[id])
        
        #To open a page, pass url to urlopen
        url = "https://numismatics.org/ocre/id/"+rec_id
        page = urlopen(url)
        html_bytes = page.read()
        html = html_bytes.decode("utf-8")
        soup = BeautifulSoup(html, "html.parser")    
        main_tag = soup.find_all("div", {"class": "col-md-12"})

        try:
            attribute = main_tag[2].find('a') 
        
            href = attribute['href']
        

            #Download file        
            id_csv = pd.read_csv(href)
            id_csv.to_csv(path2+rec_id+'.csv', index=False)
        
        
        except Exception as e:
            #print(e)
            pass

    return checkpoint

# %%
# For some links, there won't be any associated CSV files
start= 0
extract_csv(df, start)
# Out:
# 100%|██████████| 41700/41700 [23:59:47<00:00,  2.07s/it]
# 1

# %% [markdown]
# ## Combining the collected ref data with contents

# %%
# Checking if all CSV files have the same columns. Important for merging
# ref file
ref_file_path ='data_files/data_ref_links/ric.1(2).aug.1A.csv'
ref_file= pd.read_csv(ref_file_path)
column_headers = list(ref_file.columns.values)
print(column_headers)
# Out:
# ['object', 'title', 'identifiers', 'findUri', 'findspot', 'hoard', 'collection', 'publisher', 'dataset', 'datasetTitle', 'weight', 'axis', 'diameter', 'obvThumb', 'revThumb', 'obvRef', 'revRef', 'comThumb', 'comRef', 'obvManifest', 'revManifest', 'comManifest', 'model', 'record_id']

# %%
# Merging together all the CSV files
# First, reading the path
file_path_ref = "data_files/data_csv_content"


#list all the files from the directory
file_list = os.listdir(file_path_ref)
file_list_ordered = natsorted(file_list)
file_list_ordered
# Out:
# ['.DS_Store',
#  'ric.1(2).aug.1A.csv',
#  'ric.1(2).aug.1B.csv',
#  'ric.1(2).aug.2A.csv',
#  'ric.1(2).aug.2B.csv',
#  'ric.1(2).aug.3.csv',
#  'ric.1(2).aug.4A.csv',
#  'ric.1(2).aug.4B.csv',
#  'ric.1(2).aug.5.csv',
#  'ric.1(2).aug.6.csv',
#  'ric.1(2).aug.7A.csv',
#  'ric.1(2).aug.7B.csv',
#  'ric.1(2).aug.8.csv',
#  'ric.1(2).aug.9A.csv',
#  'ric.1(2).aug.9B.csv',
#  'ric.1(2).aug.10.csv',
#  'ric.1(2).aug.11A.csv',
#  'ric.1(2).aug.11B.csv',
#  'ric.1(2).aug.12.csv',
#  'ric.1(2).aug.13.csv',
#  'ric.1(2).aug.14.csv',
#  'ric.1(2).aug.15A.csv',
#  'ric.1(2).aug.15B.csv',
#  'ric.1(2).aug.16.csv',
#  'ric.1(2).aug.18.csv',
#  'ric.1(2).aug.20.csv',
#  'ric.1(2).aug.21.csv',
#  'ric.1(2).aug.22.csv',
#  'ric.1(2).aug.23.csv',
#  'ric.1(2).aug.24.csv',
#  'ric.1(2).aug.25.csv',
#  'ric.1(2).aug.26A.csv',
#  'ric.1(2).aug.28.csv',
#  'ric.1(2).aug.29A.csv',
#  'ric.1(2).aug.29B.csv',
#  'ric.1(2).aug.31.csv',
#  'ric.1(2).aug.33A.csv',
#  'ric.1(2).aug.33B.csv',
#  'ric.1(2).aug.35.csv',
#  'ric.1(2).aug.36A.csv',
#  'ric.1(2).aug.36B.csv',
#  'ric.1(2).aug.37A.csv',
#  'ric.1(2).aug.37B.csv',
#  'ric.1(2).aug.38A.csv',
#  'ric.1(2).aug.38B.csv',
#  'ric.1(2).aug.39A.csv',
#  'ric.1(2).aug.40A.csv',
#  'ric.1(2).aug.40B.csv',
#  'ric.1(2).aug.41.csv',
#  'ric.1(2).aug.42A.csv',
#  'ric.1(2).aug.42B.csv',
#  'ric.1(2).aug.43A.csv',
#  'ric.1(2).aug.43B.csv',
#  'ric.1(2).aug.44.csv',
#  'ric.1(2).aug.45.csv',
#  'ric.1(2).aug.46.csv',
#  'ric.1(2).aug.47A.csv',
#  'ric.1(2).aug.47B.csv',
#  'ric.1(2).aug.48.csv',
#  'ric.1(2).aug.50A.csv',
#  'ric.1(2).aug.51.csv',
#  'ric.1(2).aug.52A.csv',
#  'ric.1(2).aug.53A.csv',
#  'ric.1(2).aug.53B.csv',
#  'ric.1(2).aug.54A.csv',
#  'ric.1(2).aug.54B.csv',
#  'ric.1(2).aug.55.csv',
#  'ric.1(2).aug.56B.csv',
#  'ric.1(2).aug.57.csv',
#  'ric.1(2).aug.58.csv',
#  'ric.1(2).aug.59.csv',
#  'ric.1(2).aug.60.csv',
#  'ric.1(2).aug.61.csv',
#  'ric.1(2).aug.62.csv',
#  'ric.1(2).aug.63A.csv',
#  'ric.1(2).aug.64.csv',
#  'ric.1(2).aug.65.csv',
#  'ric.1(2).aug.66.csv',
#  'ric.1(2).aug.67.csv',
#  'ric.1(2).aug.68.csv',
#  'ric.1(2).aug.69A.csv',
#  'ric.1(2).aug.69B.csv',
#  'ric.1(2).aug.70A.csv',
#  'ric.1(2).aug.71.csv',
#  'ric.1(2).aug.72.csv',
#  'ric.1(2).aug.74A.csv',
#  'ric.1(2).aug.74B.csv',
#  'ric.1(2).aug.75A.csv',
#  'ric.1(2).aug.75B.csv',
#  'ric.1(2).aug.77A.csv',
#  'ric.1(2).aug.77B.csv',
#  'ric.1(2).aug.78.csv',
#  'ric.1(2).aug.79A.csv',
#  'ric.1(2).aug.79B.csv',
#  'ric.1(2).aug.80A.csv',
#  'ric.1(2).aug.80B.csv',
#  'ric.1(2).aug.81.csv',
#  'ric.1(2).aug.82A.csv',
#  'ric.1(2).aug.82B.csv',
#  'ric.1(2).aug.83.csv',
#  'ric.1(2).aug.85A.csv',
#  'ric.1(2).aug.86A.csv',
#  'ric.1(2).aug.86B.csv',
#  'ric.1(2).aug.87A.csv',
#  'ric.1(2).aug.87B.csv',
#  'ric.1(2).aug.88.csv',
#  'ric.1(2).aug.89.csv',
#  'ric.1(2).aug.90.csv',
#  'ric.1(2).aug.91.csv',
#  'ric.1(2).aug.92.csv',
#  'ric.1(2).aug.93.csv',
#  'ric.1(2).aug.94.csv',
#  'ric.1(2).aug.95.csv',
#  'ric.1(2).aug.96.csv',
#  'ric.1(2).aug.97.csv',
#  'ric.1(2).aug.98.csv',
#  'ric.1(2).aug.99.csv',
#  'ric.1(2).aug.100.csv',
#  'ric.1(2).aug.101.csv',
#  'ric.1(2).aug.102.csv',
#  'ric.1(2).aug.103.csv',
#  'ric.1(2).aug.104.csv',
#  'ric.1(2).aug.105A.csv',
#  'ric.1(2).aug.105B.csv',
#  'ric.1(2).aug.107A.csv',
#  'ric.1(2).aug.107B.csv',
#  'ric.1(2).aug.108A.csv',
#  'ric.1(2).aug.108B.csv',
#  'ric.1(2).aug.109.csv',
#  'ric.1(2).aug.110.csv',
#  'ric.1(2).aug.111.csv',
#  'ric.1(2).aug.112.csv',
#  'ric.1(2).aug.113A.csv',
#  'ric.1(2).aug.113B.csv',
#  'ric.1(2).aug.114.csv',
#  'ric.1(2).aug.115.csv',
#  'ric.1(2).aug.116.csv',
#  'ric.1(2).aug.117.csv',
#  'ric.1(2).aug.118.csv',
#  'ric.1(2).aug.119.csv',
#  'ric.1(2).aug.120.csv',
#  'ric.1(2).aug.121.csv',
#  'ric.1(2).aug.122.csv',
#  'ric.1(2).aug.123.csv',
#  'ric.1(2).aug.124.csv',
#  'ric.1(2).aug.125.csv',
#  'ric.1(2).aug.126.csv',
#  'ric.1(2).aug.127.csv',
#  'ric.1(2).aug.128.csv',
#  'ric.1(2).aug.129.csv',
#  'ric.1(2).aug.130.csv',
#  'ric.1(2).aug.131.csv',
#  'ric.1(2).aug.134A.csv',
#  'ric.1(2).aug.134B.csv',
#  'ric.1(2).aug.135.csv',
#  'ric.1(2).aug.136.csv',
#  'ric.1(2).aug.137.csv',
#  'ric.1(2).aug.138.csv',
#  'ric.1(2).aug.139.csv',
#  'ric.1(2).aug.140.csv',
#  'ric.1(2).aug.141.csv',
#  'ric.1(2).aug.142.csv',
#  'ric.1(2).aug.143.csv',
#  'ric.1(2).aug.144.csv',
#  'ric.1(2).aug.145.csv',
#  'ric.1(2).aug.146.csv',
#  'ric.1(2).aug.147.csv',
#  'ric.1(2).aug.148.csv',
#  'ric.1(2).aug.149A.csv',
#  'ric.1(2).aug.149B.csv',
#  'ric.1(2).aug.150A.csv',
#  'ric.1(2).aug.151.csv',
#  'ric.1(2).aug.152.csv',
#  'ric.1(2).aug.153.csv',
#  'ric.1(2).aug.154.csv',
#  'ric.1(2).aug.155.csv',
#  'ric.1(2).aug.156.csv',
#  'ric.1(2).aug.157.csv',
#  'ric.1(2).aug.158.csv',
#  'ric.1(2).aug.159.csv',
#  'ric.1(2).aug.160.csv',
#  'ric.1(2).aug.161.csv',
#  'ric.1(2).aug.162A.csv',
#  'ric.1(2).aug.162B.csv',
#  'ric.1(2).aug.163.csv',
#  'ric.1(2).aug.164A.csv',
#  'ric.1(2).aug.164B.csv',
#  'ric.1(2).aug.165A.csv',
#  'ric.1(2).aug.165B.csv',
#  'ric.1(2).aug.166A.csv',
#  'ric.1(2).aug.166B.csv',
#  'ric.1(2).aug.167A.csv',
#  'ric.1(2).aug.167B.csv',
#  'ric.1(2).aug.168.csv',
#  'ric.1(2).aug.169.csv',
#  'ric.1(2).aug.170.csv',
#  'ric.1(2).aug.171A.csv',
#  'ric.1(2).aug.172.csv',
#  'ric.1(2).aug.173A.csv',
#  'ric.1(2).aug.173B.csv',
#  'ric.1(2).aug.174.csv',
#  'ric.1(2).aug.176A.csv',
#  'ric.1(2).aug.176B.csv',
#  'ric.1(2).aug.177.csv',
#  'ric.1(2).aug.178A.csv',
#  'ric.1(2).aug.179.csv',
#  'ric.1(2).aug.180.csv',
#  'ric.1(2).aug.181.csv',
#  'ric.1(2).aug.182.csv',
#  'ric.1(2).aug.183.csv',
#  'ric.1(2).aug.184.csv',
#  'ric.1(2).aug.185.csv',
#  'ric.1(2).aug.186A.csv',
#  'ric.1(2).aug.186B.csv',
#  'ric.1(2).aug.187A.csv',
#  'ric.1(2).aug.187B.csv',
#  'ric.1(2).aug.188A.csv',
#  'ric.1(2).aug.188B.csv',
#  'ric.1(2).aug.189A.csv',
#  'ric.1(2).aug.189B.csv',
#  'ric.1(2).aug.190A.csv',
#  'ric.1(2).aug.190B.csv',
#  'ric.1(2).aug.191.csv',
#  'ric.1(2).aug.192A.csv',
#  'ric.1(2).aug.192B.csv',
#  'ric.1(2).aug.193A.csv',
#  'ric.1(2).aug.193B.csv',
#  'ric.1(2).aug.194A.csv',
#  'ric.1(2).aug.194B.csv',
#  'ric.1(2).aug.195.csv',
#  'ric.1(2).aug.196.csv',
#  'ric.1(2).aug.197A.csv',
#  'ric.1(2).aug.197B.csv',
#  'ric.1(2).aug.198.csv',
#  'ric.1(2).aug.199.csv',
#  'ric.1(2).aug.200.csv',
#  'ric.1(2).aug.201A.csv',
#  'ric.1(2).aug.201B.csv',
#  'ric.1(2).aug.202.csv',
#  'ric.1(2).aug.203.csv',
#  'ric.1(2).aug.206.csv',
#  'ric.1(2).aug.207.csv',
#  'ric.1(2).aug.208.csv',
#  'ric.1(2).aug.209.csv',
#  'ric.1(2).aug.210.csv',
#  'ric.1(2).aug.211.csv',
#  'ric.1(2).aug.212.csv',
#  'ric.1(2).aug.215.csv',
#  'ric.1(2).aug.216.csv',
#  'ric.1(2).aug.217.csv',
#  'ric.1(2).aug.219.csv',
#  'ric.1(2).aug.220.csv',
#  'ric.1(2).aug.221.csv',
#  'ric.1(2).aug.222.csv',
#  'ric.1(2).aug.223.csv',
#  'ric.1(2).aug.224.csv',
#  'ric.1(2).aug.225.csv',
#  'ric.1(2).aug.226.csv',
#  'ric.1(2).aug.227.csv',
#  'ric.1(2).aug.228.csv',
#  'ric.1(2).aug.229.csv',
#  'ric.1(2).aug.230.csv',
#  'ric.1(2).aug.231A.csv',
#  'ric.1(2).aug.232.csv',
#  'ric.1(2).aug.233.csv',
#  'ric.1(2).aug.234.csv',
#  'ric.1(2).aug.235.csv',
#  'ric.1(2).aug.236A.csv',
#  'ric.1(2).aug.236B.csv',
#  'ric.1(2).aug.237.csv',
#  'ric.1(2).aug.238A.csv',
#  'ric.1(2).aug.239.csv',
#  'ric.1(2).aug.240.csv',
#  'ric.1(2).aug.241A.csv',
#  'ric.1(2).aug.241B.csv',
#  'ric.1(2).aug.242.csv',
#  'ric.1(2).aug.243.csv',
#  'ric.1(2).aug.244.csv',
#  'ric.1(2).aug.245.csv',
#  'ric.1(2).aug.246.csv',
#  'ric.1(2).aug.247.csv',
#  'ric.1(2).aug.248A.csv',
#  'ric.1(2).aug.249.csv',
#  'ric.1(2).aug.250A.csv',
#  'ric.1(2).aug.250B.csv',
#  'ric.1(2).aug.251.csv',
#  'ric.1(2).aug.252.csv',
#  'ric.1(2).aug.253.csv',
#  'ric.1(2).aug.254A.csv',
#  'ric.1(2).aug.254B.csv',
#  'ric.1(2).aug.255.csv',
#  'ric.1(2).aug.256.csv',
#  'ric.1(2).aug.257.csv',
#  'ric.1(2).aug.263.csv',
#  'ric.1(2).aug.264.csv',
#  'ric.1(2).aug.265A.csv',
#  'ric.1(2).aug.265B.csv',
#  'ric.1(2).aug.266.csv',
#  'ric.1(2).aug.267.csv',
#  'ric.1(2).aug.269A.csv',
#  'ric.1(2).aug.270.csv',
#  'ric.1(2).aug.271.csv',
#  'ric.1(2).aug.272.csv',
#  'ric.1(2).aug.274.csv',
#  'ric.1(2).aug.275A.csv',
#  'ric.1(2).aug.276.csv',
#  'ric.1(2).aug.278.csv',
#  'ric.1(2).aug.279.csv',
#  'ric.1(2).aug.281.csv',
#  'ric.1(2).aug.282.csv',
#  'ric.1(2).aug.283.csv',
#  'ric.1(2).aug.284.csv',
#  'ric.1(2).aug.286.csv',
#  'ric.1(2).aug.287.csv',
#  'ric.1(2).aug.288.csv',
#  'ric.1(2).aug.289.csv',
#  'ric.1(2).aug.290.csv',
#  'ric.1(2).aug.291.csv',
#  'ric.1(2).aug.292.csv',
#  'ric.1(2).aug.293.csv',
#  'ric.1(2).aug.294.csv',
#  'ric.1(2).aug.295.csv',
#  'ric.1(2).aug.296.csv',
#  'ric.1(2).aug.297.csv',
#  'ric.1(2).aug.298.csv',
#  'ric.1(2).aug.299.csv',
#  'ric.1(2).aug.300.csv',
#  'ric.1(2).aug.301.csv',
#  'ric.1(2).aug.302.csv',
#  'ric.1(2).aug.303.csv',
#  'ric.1(2).aug.304.csv',
#  'ric.1(2).aug.306.csv',
#  'ric.1(2).aug.307.csv',
#  'ric.1(2).aug.308.csv',
#  'ric.1(2).aug.309.csv',
#  'ric.1(2).aug.310.csv',
#  'ric.1(2).aug.311.csv',
#  'ric.1(2).aug.312.csv',
#  'ric.1(2).aug.313.csv',
#  'ric.1(2).aug.314.csv',
#  'ric.1(2).aug.315.csv',
#  'ric.1(2).aug.316.csv',
#  'ric.1(2).aug.317.csv',
#  'ric.1(2).aug.318.csv',
#  'ric.1(2).aug.319.csv',
#  'ric.1(2).aug.320.csv',
#  'ric.1(2).aug.321.csv',
#  'ric.1(2).aug.322.csv',
#  'ric.1(2).aug.323.csv',
#  'ric.1(2).aug.324.csv',
#  'ric.1(2).aug.325.csv',
#  'ric.1(2).aug.326.csv',
#  'ric.1(2).aug.327.csv',
#  'ric.1(2).aug.328.csv',
#  'ric.1(2).aug.329.csv',
#  'ric.1(2).aug.330.csv',
#  'ric.1(2).aug.332.csv',
#  'ric.1(2).aug.333.csv',
#  'ric.1(2).aug.334.csv',
#  'ric.1(2).aug.335.csv',
#  'ric.1(2).aug.336.csv',
#  'ric.1(2).aug.338.csv',
#  'ric.1(2).aug.339.csv',
#  'ric.1(2).aug.340.csv',
#  'ric.1(2).aug.341.csv',
#  'ric.1(2).aug.342.csv',
#  'ric.1(2).aug.343.csv',
#  'ric.1(2).aug.344.csv',
#  'ric.1(2).aug.345.csv',
#  'ric.1(2).aug.346.csv',
#  'ric.1(2).aug.347.csv',
#  'ric.1(2).aug.348.csv',
#  'ric.1(2).aug.349.csv',
#  'ric.1(2).aug.350.csv',
#  'ric.1(2).aug.351.csv',
#  'ric.1(2).aug.352.csv',
#  'ric.1(2).aug.353.csv',
#  'ric.1(2).aug.354.csv',
#  'ric.1(2).aug.355.csv',
#  'ric.1(2).aug.356.csv',
#  'ric.1(2).aug.357.csv',
#  'ric.1(2).aug.358.csv',
#  'ric.1(2).aug.359.csv',
#  'ric.1(2).aug.360.csv',
#  'ric.1(2).aug.361.csv',
#  'ric.1(2).aug.362.csv',
#  'ric.1(2).aug.363.csv',
#  'ric.1(2).aug.364.csv',
#  'ric.1(2).aug.365.csv',
#  'ric.1(2).aug.366.csv',
#  'ric.1(2).aug.367.csv',
#  'ric.1(2).aug.368.csv',
#  'ric.1(2).aug.369.csv',
#  'ric.1(2).aug.370.csv',
#  'ric.1(2).aug.371.csv',
#  'ric.1(2).aug.372.csv',
#  'ric.1(2).aug.373.csv',
#  'ric.1(2).aug.374.csv',
#  'ric.1(2).aug.375.csv',
#  'ric.1(2).aug.376.csv',
#  'ric.1(2).aug.377.csv',
#  'ric.1(2).aug.378.csv',
#  'ric.1(2).aug.379.csv',
#  'ric.1(2).aug.380.csv',
#  'ric.1(2).aug.381.csv',
#  'ric.1(2).aug.382.csv',
#  'ric.1(2).aug.383.csv',
#  'ric.1(2).aug.384.csv',
#  'ric.1(2).aug.385.csv',
#  'ric.1(2).aug.386.csv',
#  'ric.1(2).aug.387.csv',
#  'ric.1(2).aug.388.csv',
#  'ric.1(2).aug.389.csv',
#  'ric.1(2).aug.390.csv',
#  'ric.1(2).aug.391.csv',
#  'ric.1(2).aug.392.csv',
#  'ric.1(2).aug.395.csv',
#  'ric.1(2).aug.397.csv',
#  'ric.1(2).aug.398.csv',
#  'ric.1(2).aug.399.csv',
#  'ric.1(2).aug.400.csv',
#  'ric.1(2).aug.401.csv',
#  'ric.1(2).aug.402.csv',
#  'ric.1(2).aug.403.csv',
#  'ric.1(2).aug.404.csv',
#  'ric.1(2).aug.405.csv',
#  'ric.1(2).aug.407.csv',
#  'ric.1(2).aug.408.csv',
#  'ric.1(2).aug.409.csv',
#  'ric.1(2).aug.410.csv',
#  'ric.1(2).aug.411.csv',
#  'ric.1(2).aug.412.csv',
#  'ric.1(2).aug.414.csv',
#  'ric.1(2).aug.415.csv',
#  'ric.1(2).aug.416.csv',
#  'ric.1(2).aug.417.csv',
#  'ric.1(2).aug.418.csv',
#  'ric.1(2).aug.419.csv',
#  'ric.1(2).aug.420.csv',
#  'ric.1(2).aug.421.csv',
#  'ric.1(2).aug.422.csv',
#  'ric.1(2).aug.423.csv',
#  'ric.1(2).aug.424.csv',
#  'ric.1(2).aug.425.csv',
#  'ric.1(2).aug.426.csv',
#  'ric.1(2).aug.426A.csv',
#  'ric.1(2).aug.427.csv',
#  'ric.1(2).aug.428.csv',
#  'ric.1(2).aug.429.csv',
#  'ric.1(2).aug.430.csv',
#  'ric.1(2).aug.431.csv',
#  'ric.1(2).aug.432.csv',
#  'ric.1(2).aug.433.csv',
#  'ric.1(2).aug.434.csv',
#  'ric.1(2).aug.435.csv',
#  'ric.1(2).aug.436.csv',
#  'ric.1(2).aug.437.csv',
#  'ric.1(2).aug.438.csv',
#  'ric.1(2).aug.439.csv',
#  'ric.1(2).aug.440.csv',
#  'ric.1(2).aug.441.csv',
#  'ric.1(2).aug.442.csv',
#  'ric.1(2).aug.443.csv',
#  'ric.1(2).aug.444.csv',
#  'ric.1(2).aug.445.csv',
#  'ric.1(2).aug.446.csv',
#  'ric.1(2).aug.447.csv',
#  'ric.1(2).aug.449.csv',
#  'ric.1(2).aug.450.csv',
#  'ric.1(2).aug.451.csv',
#  'ric.1(2).aug.452.csv',
#  'ric.1(2).aug.453.csv',
#  'ric.1(2).aug.454.csv',
#  'ric.1(2).aug.455.csv',
#  'ric.1(2).aug.456.csv',
#  'ric.1(2).aug.457.csv',
#  'ric.1(2).aug.458.csv',
#  'ric.1(2).aug.459.csv',
#  'ric.1(2).aug.460.csv',
#  'ric.1(2).aug.461.csv',
#  'ric.1(2).aug.462.csv',
#  'ric.1(2).aug.463.csv',
#  'ric.1(2).aug.464.csv',
#  'ric.1(2).aug.465.csv',
#  'ric.1(2).aug.466.csv',
#  'ric.1(2).aug.467.csv',
#  'ric.1(2).aug.468.csv',
#  'ric.1(2).aug.469.csv',
#  'ric.1(2).aug.470.csv',
#  'ric.1(2).aug.471.csv',
#  'ric.1(2).aug.472.csv',
#  'ric.1(2).aug.473.csv',
#  'ric.1(2).aug.475.csv',
#  'ric.1(2).aug.476.csv',
#  'ric.1(2).aug.477.csv',
#  'ric.1(2).aug.478.csv',
#  'ric.1(2).aug.479.csv',
#  'ric.1(2).aug.481.csv',
#  'ric.1(2).aug.483.csv',
#  'ric.1(2).aug.484.csv',
#  'ric.1(2).aug.485.csv',
#  'ric.1(2).aug.486.csv',
#  'ric.1(2).aug.487.csv',
#  'ric.1(2).aug.488.csv',
#  'ric.1(2).aug.489.csv',
#  'ric.1(2).aug.490.csv',
#  'ric.1(2).aug.491.csv',
#  'ric.1(2).aug.492.csv',
#  'ric.1(2).aug.493.csv',
#  'ric.1(2).aug.494.csv',
#  'ric.1(2).aug.495.csv',
#  'ric.1(2).aug.497.csv',
#  'ric.1(2).aug.498.csv',
#  'ric.1(2).aug.501.csv',
#  'ric.1(2).aug.502.csv',
#  'ric.1(2).aug.503.csv',
#  'ric.1(2).aug.504.csv',
#  'ric.1(2).aug.506.csv',
#  'ric.1(2).aug.507.csv',
#  'ric.1(2).aug.508.csv',
#  'ric.1(2).aug.509.csv',
#  'ric.1(2).aug.510.csv',
#  'ric.1(2).aug.511.csv',
#  'ric.1(2).aug.512.csv',
#  'ric.1(2).aug.513.csv',
#  'ric.1(2).aug.514.csv',
#  'ric.1(2).aug.515.csv',
#  'ric.1(2).aug.516.csv',
#  'ric.1(2).aug.517.csv',
#  'ric.1(2).aug.518.csv',
#  'ric.1(2).aug.519.csv',
#  'ric.1(2).aug.520.csv',
#  'ric.1(2).aug.521.csv',
#  'ric.1(2).aug.522.csv',
#  'ric.1(2).aug.525.csv',
#  'ric.1(2).aug.526.csv',
#  'ric.1(2).aug.528.csv',
#  'ric.1(2).aug.529.csv',
#  'ric.1(2).aug.530.csv',
#  'ric.1(2).aug.531.csv',
#  'ric.1(2).aug.532.csv',
#  'ric.1(2).aug.534.csv',
#  'ric.1(2).aug.535.csv',
#  'ric.1(2).aug.540.csv',
#  'ric.1(2).aug.541.csv',
#  'ric.1(2).aug.542.csv',
#  'ric.1(2).aug.543A.csv',
#  'ric.1(2).aug.543B.csv',
#  'ric.1(2).aug.545.csv',
#  'ric.1(2).aug.547B.csv',
#  'ric.1(2).cl.1.csv',
#  'ric.1(2).cl.2.csv',
#  'ric.1(2).cl.3.csv',
#  'ric.1(2).cl.4.csv',
#  'ric.1(2).cl.5.csv',
#  'ric.1(2).cl.6.csv',
#  'ric.1(2).cl.7.csv',
#  'ric.1(2).cl.8.csv',
#  'ric.1(2).cl.9.csv',
#  'ric.1(2).cl.10.csv',
#  'ric.1(2).cl.11.csv',
#  'ric.1(2).cl.12.csv',
#  'ric.1(2).cl.13.csv',
#  'ric.1(2).cl.14.csv',
#  'ric.1(2).cl.15.csv',
#  'ric.1(2).cl.16.csv',
#  'ric.1(2).cl.17.csv',
#  'ric.1(2).cl.18.csv',
#  'ric.1(2).cl.19.csv',
#  'ric.1(2).cl.20.csv',
#  'ric.1(2).cl.21.csv',
#  'ric.1(2).cl.22.csv',
#  'ric.1(2).cl.23.csv',
#  'ric.1(2).cl.24.csv',
#  'ric.1(2).cl.25.csv',
#  'ric.1(2).cl.26.csv',
#  'ric.1(2).cl.27.csv',
#  'ric.1(2).cl.28.csv',
#  'ric.1(2).cl.29.csv',
#  'ric.1(2).cl.31.csv',
#  'ric.1(2).cl.32.csv',
#  'ric.1(2).cl.33.csv',
#  'ric.1(2).cl.34.csv',
#  'ric.1(2).cl.35.csv',
#  'ric.1(2).cl.36.csv',
#  'ric.1(2).cl.37.csv',
#  'ric.1(2).cl.38.csv',
#  'ric.1(2).cl.39.csv',
#  'ric.1(2).cl.40.csv',
#  'ric.1(2).cl.41.csv',
#  'ric.1(2).cl.42.csv',
#  'ric.1(2).cl.44.csv',
#  'ric.1(2).cl.45.csv',
#  'ric.1(2).cl.46.csv',
#  'ric.1(2).cl.47.csv',
#  'ric.1(2).cl.48.csv',
#  'ric.1(2).cl.49.csv',
#  'ric.1(2).cl.50.csv',
#  'ric.1(2).cl.51.csv',
#  'ric.1(2).cl.52.csv',
#  'ric.1(2).cl.53.csv',
#  'ric.1(2).cl.54.csv',
#  'ric.1(2).cl.55.csv',
#  'ric.1(2).cl.56.csv',
#  'ric.1(2).cl.57.csv',
#  'ric.1(2).cl.58.csv',
#  'ric.1(2).cl.59.csv',
#  'ric.1(2).cl.60.csv',
#  'ric.1(2).cl.61.csv',
#  'ric.1(2).cl.62.csv',
#  'ric.1(2).cl.63.csv',
#  'ric.1(2).cl.64.csv',
#  'ric.1(2).cl.65.csv',
#  'ric.1(2).cl.66.csv',
#  'ric.1(2).cl.67.csv',
#  'ric.1(2).cl.68.csv',
#  'ric.1(2).cl.69.csv',
#  'ric.1(2).cl.70.csv',
#  'ric.1(2).cl.71.csv',
#  'ric.1(2).cl.72.csv',
#  'ric.1(2).cl.73.csv',
#  'ric.1(2).cl.74.csv',
#  'ric.1(2).cl.75.csv',
#  'ric.1(2).cl.76.csv',
#  'ric.1(2).cl.77.csv',
#  'ric.1(2).cl.78.csv',
#  'ric.1(2).cl.79.csv',
#  'ric.1(2).cl.80.csv',
#  'ric.1(2).cl.81.csv',
#  'ric.1(2).cl.82.csv',
#  'ric.1(2).cl.83.csv',
#  'ric.1(2).cl.84.csv',
#  'ric.1(2).cl.85.csv',
#  'ric.1(2).cl.87.csv',
#  'ric.1(2).cl.88.csv',
#  'ric.1(2).cl.89.csv',
#  'ric.1(2).cl.90.csv',
#  'ric.1(2).cl.91.csv',
#  'ric.1(2).cl.92.csv',
#  'ric.1(2).cl.93.csv',
#  'ric.1(2).cl.94.csv',
#  'ric.1(2).cl.95.csv',
#  'ric.1(2).cl.96.csv',
#  'ric.1(2).cl.97.csv',
#  'ric.1(2).cl.98.csv',
#  'ric.1(2).cl.99.csv',
#  'ric.1(2).cl.100.csv',
#  'ric.1(2).cl.101.csv',
#  'ric.1(2).cl.102.csv',
#  'ric.1(2).cl.103.csv',
#  'ric.1(2).cl.104.csv',
#  'ric.1(2).cl.105.csv',
#  'ric.1(2).cl.106.csv',
#  'ric.1(2).cl.107.csv',
#  'ric.1(2).cl.108.csv',
#  'ric.1(2).cl.109.csv',
#  'ric.1(2).cl.110.csv',
#  'ric.1(2).cl.111.csv',
#  'ric.1(2).cl.112.csv',
#  'ric.1(2).cl.113.csv',
#  'ric.1(2).cl.114.csv',
#  'ric.1(2).cl.115.csv',
#  'ric.1(2).cl.116.csv',
#  'ric.1(2).cl.117.csv',
#  'ric.1(2).cl.118.csv',
#  'ric.1(2).cl.119.csv',
#  'ric.1(2).cl.120.csv',
#  'ric.1(2).cl.121.csv',
#  'ric.1(2).cl.122.csv',
#  'ric.1(2).cl.123.csv',
#  'ric.1(2).cl.124.csv',
#  'ric.1(2).cl.126.csv',
#  'ric.1(2).clm.2.csv',
#  'ric.1(2).clm.6.csv',
#  'ric.1(2).clm.8.csv',
#  'ric.1(2).clm.9.csv',
#  'ric.1(2).clm.10.csv',
#  'ric.1(2).clm.11.csv',
#  'ric.1(2).clm.13.csv',
#  'ric.1(2).clm.17.csv',
#  'ric.1(2).clm.21.csv',
#  'ric.1(2).clm.22.csv',
#  'ric.1(2).clm.26.csv',
#  'ric.1(2).clm.28.csv',
#  'ric.1(2).clm.29.csv',
#  'ric.1(2).clm.34.csv',
#  'ric.1(2).clm.35.csv',
#  'ric.1(2).clm.41.csv',
#  'ric.1(2).cw.4.csv',
#  'ric.1(2).cw.17.csv',
#  'ric.1(2).cw.27.csv',
#  'ric.1(2).cw.39.csv',
#  'ric.1(2).cw.51.csv',
#  'ric.1(2).cw.58.csv',
#  'ric.1(2).cw.59.csv',
#  'ric.1(2).cw.61.csv',
#  'ric.1(2).cw.66.csv',
#  'ric.1(2).cw.72.csv',
#  'ric.1(2).cw.73B.csv',
#  'ric.1(2).cw.118.csv',
#  'ric.1(2).cw.121.csv',
#  'ric.1(2).cw.127A.csv',
#  'ric.1(2).gai.1.csv',
#  'ric.1(2).gai.2.csv',
#  'ric.1(2).gai.4.csv',
#  'ric.1(2).gai.5.csv',
#  'ric.1(2).gai.6.csv',
#  'ric.1(2).gai.7.csv',
#  'ric.1(2).gai.8.csv',
#  'ric.1(2).gai.10.csv',
#  'ric.1(2).gai.11.csv',
#  'ric.1(2).gai.12.csv',
#  'ric.1(2).gai.13.csv',
#  'ric.1(2).gai.14.csv',
#  'ric.1(2).gai.15.csv',
#  'ric.1(2).gai.16.csv',
#  'ric.1(2).gai.17.csv',
#  'ric.1(2).gai.18.csv',
#  'ric.1(2).gai.19.csv',
#  'ric.1(2).gai.20.csv',
#  'ric.1(2).gai.21.csv',
#  'ric.1(2).gai.22.csv',
#  'ric.1(2).gai.23.csv',
#  'ric.1(2).gai.24.csv',
#  'ric.1(2).gai.25.csv',
#  'ric.1(2).gai.26.csv',
#  'ric.1(2).gai.27.csv',
#  'ric.1(2).gai.28.csv',
#  'ric.1(2).gai.29.csv',
#  'ric.1(2).gai.31.csv',
#  'ric.1(2).gai.32.csv',
#  'ric.1(2).gai.33.csv',
#  'ric.1(2).gai.34.csv',
#  'ric.1(2).gai.35.csv',
#  'ric.1(2).gai.36.csv',
#  'ric.1(2).gai.37.csv',
#  'ric.1(2).gai.38.csv',
#  'ric.1(2).gai.39.csv',
#  'ric.1(2).gai.40.csv',
#  'ric.1(2).gai.42.csv',
#  'ric.1(2).gai.43.csv',
#  'ric.1(2).gai.44.csv',
#  'ric.1(2).gai.45.csv',
#  'ric.1(2).gai.46.csv',
#  'ric.1(2).gai.47.csv',
#  'ric.1(2).gai.48.csv',
#  'ric.1(2).gai.49.csv',
#  'ric.1(2).gai.50.csv',
#  'ric.1(2).gai.51.csv',
#  'ric.1(2).gai.52.csv',
#  'ric.1(2).gai.53.csv',
#  'ric.1(2).gai.54.csv',
#  'ric.1(2).gai.55.csv',
#  'ric.1(2).gai.56.csv',
#  'ric.1(2).gai.57.csv',
#  'ric.1(2).gai.58.csv',
#  'ric.1(2).gai.59.csv',
#  'ric.1(2).gai.60.csv',
#  'ric.1(2).gai.61.csv',
#  'ric.1(2).gai.62.csv',
#  'ric.1(2).gai.63.csv',
#  'ric.1(2).gal.1.csv',
#  'ric.1(2).gal.2.csv',
#  'ric.1(2).gal.7.csv',
#  'ric.1(2).gal.9.csv',
#  'ric.1(2).gal.10.csv',
#  'ric.1(2).gal.11.csv',
#  'ric.1(2).gal.12.csv',
#  'ric.1(2).gal.13.csv',
#  'ric.1(2).gal.14.csv',
#  'ric.1(2).gal.15.csv',
#  'ric.1(2).gal.18.csv',
#  'ric.1(2).gal.19.csv',
#  'ric.1(2).gal.20.csv',
#  'ric.1(2).gal.21.csv',
#  'ric.1(2).gal.23.csv',
#  'ric.1(2).gal.25.csv',
#  'ric.1(2).gal.27.csv',
#  'ric.1(2).gal.28.csv',
#  'ric.1(2).gal.29.csv',
#  'ric.1(2).gal.30.csv',
#  'ric.1(2).gal.31.csv',
#  'ric.1(2).gal.32.csv',
#  'ric.1(2).gal.35.csv',
#  'ric.1(2).gal.36.csv',
#  'ric.1(2).gal.39.csv',
#  'ric.1(2).gal.40.csv',
#  'ric.1(2).gal.41.csv',
#  'ric.1(2).gal.42.csv',
#  'ric.1(2).gal.43.csv',
#  'ric.1(2).gal.44.csv',
#  'ric.1(2).gal.45.csv',
#  'ric.1(2).gal.46.csv',
#  'ric.1(2).gal.47.csv',
#  'ric.1(2).gal.48.csv',
#  'ric.1(2).gal.49.csv',
#  'ric.1(2).gal.50.csv',
#  'ric.1(2).gal.52.csv',
#  'ric.1(2).gal.53.csv',
#  'ric.1(2).gal.54.csv',
#  'ric.1(2).gal.55.csv',
#  'ric.1(2).gal.57.csv',
#  'ric.1(2).gal.58.csv',
#  'ric.1(2).gal.59.csv',
#  'ric.1(2).gal.60.csv',
#  'ric.1(2).gal.61.csv',
#  'ric.1(2).gal.62.csv',
#  'ric.1(2).gal.63.csv',
#  'ric.1(2).gal.64.csv',
#  'ric.1(2).gal.66.csv',
#  'ric.1(2).gal.67.csv',
#  'ric.1(2).gal.68.csv',
#  'ric.1(2).gal.70.csv',
#  'ric.1(2).gal.71.csv',
#  'ric.1(2).gal.72.csv',
#  'ric.1(2).gal.73.csv',
#  'ric.1(2).gal.78.csv',
#  'ric.1(2).gal.80.csv',
#  'ric.1(2).gal.81.csv',
#  'ric.1(2).gal.83.csv',
#  'ric.1(2).gal.85.csv',
#  'ric.1(2).gal.86.csv',
#  'ric.1(2).gal.87.csv',
#  'ric.1(2).gal.88.csv',
#  'ric.1(2).gal.89.csv',
#  'ric.1(2).gal.90.csv',
#  'ric.1(2).gal.91.csv',
#  'ric.1(2).gal.92.csv',
#  'ric.1(2).gal.93.csv',
#  'ric.1(2).gal.94.csv',
#  'ric.1(2).gal.95.csv',
#  'ric.1(2).gal.96.csv',
#  'ric.1(2).gal.97.csv',
#  'ric.1(2).gal.99.csv',
#  'ric.1(2).gal.103.csv',
#  'ric.1(2).gal.105.csv',
#  'ric.1(2).gal.107.csv',
#  'ric.1(2).gal.108.csv',
#  'ric.1(2).gal.109.csv',
#  'ric.1(2).gal.110.csv',
#  'ric.1(2).gal.111.csv',
#  'ric.1(2).gal.112.csv',
#  'ric.1(2).gal.113.csv',
#  'ric.1(2).gal.114.csv',
#  'ric.1(2).gal.115.csv',
#  'ric.1(2).gal.119.csv',
#  'ric.1(2).gal.120.csv',
#  'ric.1(2).gal.121.csv',
#  'ric.1(2).gal.122.csv',
#  'ric.1(2).gal.124.csv',
#  'ric.1(2).gal.125.csv',
#  'ric.1(2).gal.126.csv',
#  'ric.1(2).gal.127.csv',
#  'ric.1(2).gal.128.csv',
#  'ric.1(2).gal.129.csv',
#  'ric.1(2).gal.130.csv',
#  'ric.1(2).gal.131.csv',
#  'ric.1(2).gal.132.csv',
#  'ric.1(2).gal.133.csv',
#  'ric.1(2).gal.134.csv',
#  'ric.1(2).gal.135.csv',
#  'ric.1(2).gal.140.csv',
#  'ric.1(2).gal.141.csv',
#  'ric.1(2).gal.143.csv',
#  'ric.1(2).gal.145.csv',
#  'ric.1(2).gal.147.csv',
#  'ric.1(2).gal.149.csv',
#  'ric.1(2).gal.150.csv',
#  'ric.1(2).gal.152.csv',
#  'ric.1(2).gal.155.csv',
#  'ric.1(2).gal.156.csv',
#  'ric.1(2).gal.157.csv',
#  'ric.1(2).gal.158.csv',
#  'ric.1(2).gal.160.csv',
#  'ric.1(2).gal.161.csv',
#  'ric.1(2).gal.162.csv',
#  'ric.1(2).gal.163.csv',
#  'ric.1(2).gal.164.csv',
#  'ric.1(2).gal.165.csv',
#  'ric.1(2).gal.166.csv',
#  'ric.1(2).gal.167.csv',
#  'ric.1(2).gal.168.csv',
#  'ric.1(2).gal.169.csv',
#  'ric.1(2).gal.170.csv',
#  'ric.1(2).gal.172.csv',
#  'ric.1(2).gal.173.csv',
#  'ric.1(2).gal.174.csv',
#  'ric.1(2).gal.175.csv',
#  'ric.1(2).gal.178.csv',
#  'ric.1(2).gal.179.csv',
#  'ric.1(2).gal.183.csv',
#  'ric.1(2).gal.184.csv',
#  'ric.1(2).gal.185.csv',
#  'ric.1(2).gal.186.csv',
#  'ric.1(2).gal.187.csv',
#  'ric.1(2).gal.188.csv',
#  'ric.1(2).gal.189.csv',
#  'ric.1(2).gal.190.csv',
#  'ric.1(2).gal.191.csv',
#  'ric.1(2).gal.193.csv',
#  'ric.1(2).gal.195.csv',
#  'ric.1(2).gal.196.csv',
#  'ric.1(2).gal.199.csv',
#  'ric.1(2).gal.200.csv',
#  'ric.1(2).gal.203.csv',
#  'ric.1(2).gal.205.csv',
#  'ric.1(2).gal.206.csv',
#  'ric.1(2).gal.210.csv',
#  'ric.1(2).gal.211.csv',
#  'ric.1(2).gal.213.csv',
#  'ric.1(2).gal.214.csv',
#  'ric.1(2).gal.216.csv',
#  'ric.1(2).gal.217.csv',
#  'ric.1(2).gal.218.csv',
#  'ric.1(2).gal.219.csv',
#  'ric.1(2).gal.221.csv',
#  'ric.1(2).gal.223.csv',
#  'ric.1(2).gal.224.csv',
#  'ric.1(2).gal.225.csv',
#  'ric.1(2).gal.227.csv',
#  'ric.1(2).gal.228.csv',
#  'ric.1(2).gal.229.csv',
#  'ric.1(2).gal.232.csv',
#  'ric.1(2).gal.233.csv',
#  'ric.1(2).gal.234.csv',
#  'ric.1(2).gal.237.csv',
#  'ric.1(2).gal.239.csv',
#  'ric.1(2).gal.240.csv',
#  'ric.1(2).gal.241.csv',
#  'ric.1(2).gal.242.csv',
#  'ric.1(2).gal.243.csv',
#  'ric.1(2).gal.244.csv',
#  'ric.1(2).gal.245.csv',
#  'ric.1(2).gal.247.csv',
#  'ric.1(2).gal.248.csv',
#  'ric.1(2).gal.251.csv',
#  'ric.1(2).gal.252.csv',
#  'ric.1(2).gal.253.csv',
#  'ric.1(2).gal.254.csv',
#  'ric.1(2).gal.255.csv',
#  'ric.1(2).gal.257.csv',
#  'ric.1(2).gal.260.csv',
#  'ric.1(2).gal.261.csv',
#  'ric.1(2).gal.262.csv',
#  'ric.1(2).gal.263.csv',
#  'ric.1(2).gal.265.csv',
#  'ric.1(2).gal.267.csv',
#  'ric.1(2).gal.268.csv',
#  'ric.1(2).gal.270.csv',
#  'ric.1(2).gal.271.csv',
#  'ric.1(2).gal.275.csv',
#  'ric.1(2).gal.276.csv',
#  'ric.1(2).gal.277.csv',
#  'ric.1(2).gal.280.csv',
#  'ric.1(2).gal.281.csv',
#  'ric.1(2).gal.282.csv',
#  'ric.1(2).gal.283.csv',
#  'ric.1(2).gal.284.csv',
#  'ric.1(2).gal.285.csv',
#  'ric.1(2).gal.286.csv',
#  'ric.1(2).gal.287.csv',
#  'ric.1(2).gal.289.csv',
#  'ric.1(2).gal.290.csv',
#  'ric.1(2).gal.291.csv',
#  'ric.1(2).gal.292.csv',
#  'ric.1(2).gal.293.csv',
#  'ric.1(2).gal.294.csv',
#  'ric.1(2).gal.295.csv',
#  'ric.1(2).gal.297.csv',
#  'ric.1(2).gal.298.csv',
#  'ric.1(2).gal.300.csv',
#  'ric.1(2).gal.301.csv',
#  'ric.1(2).gal.302.csv',
#  'ric.1(2).gal.304.csv',
#  'ric.1(2).gal.306.csv',
#  'ric.1(2).gal.307.csv',
#  'ric.1(2).gal.308.csv',
#  'ric.1(2).gal.309.csv',
#  'ric.1(2).gal.310.csv',
#  'ric.1(2).gal.311.csv',
#  'ric.1(2).gal.312.csv',
#  'ric.1(2).gal.313.csv',
#  'ric.1(2).gal.316.csv',
#  'ric.1(2).gal.320.csv',
#  'ric.1(2).gal.322.csv',
#  'ric.1(2).gal.323.csv',
#  'ric.1(2).gal.324.csv',
#  'ric.1(2).gal.326.csv',
#  'ric.1(2).gal.328.csv',
#  'ric.1(2).gal.329.csv',
#  'ric.1(2).gal.331.csv',
#  'ric.1(2).gal.333.csv',
#  'ric.1(2).gal.335.csv',
#  'ric.1(2).gal.336.csv',
#  'ric.1(2).gal.337.csv',
#  'ric.1(2).gal.340.csv',
#  'ric.1(2).gal.341.csv',
#  'ric.1(2).gal.342.csv',
#  'ric.1(2).gal.343.csv',
#  'ric.1(2).gal.344.csv',
#  ...]

# %%
# define your column names
column_names = column_headers

def column_check(path, file_list):
        abs_paths = []
        for file in range(1,len(file_list)):
                abs_path = path + '/'+file_list[file]
                abs_paths.append(abs_path)

        cols = [pd.read_csv(abs_path, nrows=0).columns for abs_path in abs_paths]

        cols_identical = [all(cols[0] == colx) for colx in cols[1:]]

        all_cols_same = all(cols_identical)
        print(all_cols_same)

# %%
column_check(file_path_ref, file_list_ordered)
# Out:
# True

# %%
# All columns are identical. Time to add the reference name to all columns
